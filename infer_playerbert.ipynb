# %% [markdown]
# # PlayerBERT Inference with V2 Event Encoder
#
# This Colab notebook streams the dataset match-by-match, computes player embeddings without loading the full raw JSONL into RAM, saves them to Drive, and supports similarity search.

# %%
from google.colab import drive
drive.mount('/content/drive')

import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))

# %%
from pathlib import Path
import json
import math
from collections import Counter, defaultdict
from urllib.request import urlopen

import torch
import torch.nn as nn
import torch.nn.functional as F

try:
    from statsbomb_gender import build_match_gender_map, build_player_metadata, majority_label
except ModuleNotFoundError:
    RAW_BASE_URL = 'https://raw.githubusercontent.com/statsbomb/open-data/master/data'

    def majority_label(counter):
        if not counter:
            return None
        return counter.most_common(1)[0][0]

    def _load_json_from_path(path):
        with Path(path).open('r', encoding='utf-8') as f:
            return json.load(f)

    def _load_json_from_url(url):
        with urlopen(url, timeout=30) as response:
            return json.load(response)

    def _iter_json_objects_for_metadata(path):
        decoder = json.JSONDecoder()
        with Path(path).open('r', encoding='utf-8') as f:
            buf = ''
            while True:
                chunk = f.read(1 << 20)
                if not chunk:
                    break
                buf += chunk
                while True:
                    buf = buf.lstrip()
                    if not buf:
                        break
                    try:
                        obj, idx = decoder.raw_decode(buf)
                    except json.JSONDecodeError:
                        break
                    yield obj
                    buf = buf[idx:]
            buf = buf.lstrip()
            if buf:
                obj, _ = decoder.raw_decode(buf)
                yield obj

    def build_match_gender_map(local_root=None, cache_path=None):
        cache_file = Path(cache_path) if cache_path else None
        if cache_file and cache_file.exists():
            with cache_file.open('r', encoding='utf-8') as f:
                return json.load(f)
        local_root = Path(local_root) if local_root else None
        competitions_path = local_root / 'competitions.json' if local_root else None
        if competitions_path and competitions_path.exists():
            competitions = _load_json_from_path(competitions_path)
            use_local = True
        else:
            competitions = _load_json_from_url(f'{RAW_BASE_URL}/competitions.json')
            use_local = False
        match_gender_map = {}
        for comp in competitions:
            competition_id = comp['competition_id']
            season_id = comp['season_id']
            gender = comp.get('competition_gender')
            if gender is None:
                continue
            if use_local:
                matches_path = local_root / 'matches' / str(competition_id) / f'{season_id}.json'
                if not matches_path.exists():
                    continue
                matches = _load_json_from_path(matches_path)
            else:
                matches = _load_json_from_url(f'{RAW_BASE_URL}/matches/{competition_id}/{season_id}.json')
            for match in matches:
                match_id = match.get('match_id')
                if match_id is not None:
                    match_gender_map[str(match_id)] = gender
        if cache_file:
            cache_file.parent.mkdir(parents=True, exist_ok=True)
            with cache_file.open('w', encoding='utf-8') as f:
                json.dump(match_gender_map, f, ensure_ascii=False, indent=2)
        return match_gender_map

    def build_player_metadata(data_path, player_ids, match_gender_map, max_rows=None):
        target_ids = set(str(pid) for pid in player_ids)
        player_names = {}
        gender_counts = defaultdict(Counter)
        rows_seen = 0
        for ev in _iter_json_objects_for_metadata(Path(data_path)):
            player_id = ev.get('player.id')
            match_id = ev.get('match_id')
            if player_id is None or match_id is None:
                continue
            player_id = str(player_id)
            if target_ids and player_id not in target_ids:
                continue
            player_name = ev.get('player.name')
            if player_name:
                player_names[player_id] = player_name
            gender = match_gender_map.get(str(match_id))
            if gender:
                gender_counts[player_id][gender] += 1
            rows_seen += 1
            if max_rows is not None and rows_seen >= max_rows:
                break
        metadata = {}
        for player_id in sorted(target_ids, key=lambda x: int(x)):
            metadata[player_id] = {
                'name': player_names.get(player_id),
                'gender': majority_label(gender_counts.get(player_id)),
            }
        return metadata

DATA_PATH = Path('/content/drive/MyDrive/MLSE/events360_v4.jsonl')
EVENT_ENCODER_CKPT = Path('/content/drive/MyDrive/MLSE/models/event_encoder_v2.pt')
PLAYERBERT_CKPT = Path('/content/drive/MyDrive/MLSE/models/playerbert_v2.pt')
EMB_OUT = Path('/content/drive/MyDrive/MLSE/models/player_embeddings_v2.pt')
NAME_OUT = Path('/content/drive/MyDrive/MLSE/models/player_embeddings_names_v2.json')
META_OUT = Path('/content/drive/MyDrive/MLSE/models/player_metadata_v2.json')
MATCH_GENDER_CACHE = Path('/content/drive/MyDrive/MLSE/match_gender_map.json')
STATSBOMB_OPEN_DATA_ROOT = Path('/content/drive/MyDrive/MLSE/open-data/data')

MAX_ROWS = None      # increase gradually after a successful run was 100000 before
SEQ_MAX_LEN = 256
SEQ_STRIDE = 128
TOP_K = 10

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)
print('Data:', DATA_PATH)
print('Event encoder ckpt:', EVENT_ENCODER_CKPT)
print('PlayerBERT ckpt:', PLAYERBERT_CKPT)
print('Player metadata out:', META_OUT)

# %%
def iter_json_objects(path):
    decoder = json.JSONDecoder()
    with Path(path).open('r', encoding='utf-8') as f:
        buf = ''
        while True:
            chunk = f.read(1 << 20)
            if not chunk:
                break
            buf += chunk
            while True:
                buf = buf.lstrip()
                if not buf:
                    break
                try:
                    obj, idx = decoder.raw_decode(buf)
                except json.JSONDecodeError:
                    break
                yield obj
                buf = buf[idx:]
        buf = buf.lstrip()
        if buf:
            obj, idx = decoder.raw_decode(buf)
            if buf[idx:].strip():
                raise json.JSONDecodeError('Trailing non-JSON content', buf, idx)
            yield obj

def normalize_value(val):
    if val is None:
        return '[UNK]'
    if isinstance(val, bool):
        return str(val)
    if isinstance(val, (dict, list)):
        return '[UNK]'
    return str(val)

def extract_numeric(ev):
    loc = ev.get('location')
    if isinstance(loc, list) and len(loc) >= 2:
        x = float(loc[0]) / 120.0
        y = float(loc[1]) / 80.0
    else:
        x, y = 0.0, 0.0
    minute = float(ev.get('minute') or 0.0) / 120.0
    second = float(ev.get('second') or 0.0) / 60.0
    period = float(ev.get('period') or 0.0) / 5.0
    duration = float(ev.get('duration') or 0.0)
    under_pressure = 1.0 if bool(ev.get('under_pressure')) else 0.0
    counterpress = 1.0 if bool(ev.get('counterpress')) else 0.0
    return [x, y, minute, second, period, math.log1p(max(0.0, duration)), under_pressure, counterpress]

def extract_freeze_frame(ev, max_players=22):
    loc = ev.get('location')
    ax = float(loc[0]) if isinstance(loc, list) and len(loc) >= 2 else 0.0
    ay = float(loc[1]) if isinstance(loc, list) and len(loc) >= 2 else 0.0
    players = []
    freeze_frame = ev.get('freeze_frame') or []
    if isinstance(freeze_frame, list):
        for p in freeze_frame:
            if not isinstance(p, dict):
                continue
            ploc = p.get('location')
            if not isinstance(ploc, list) or len(ploc) < 2:
                continue
            dx = (float(ploc[0]) - ax) / 120.0
            dy = (float(ploc[1]) - ay) / 80.0
            dist = math.sqrt(dx * dx + dy * dy)
            angle = math.atan2(dy, dx + 1e-8)
            players.append([
                dx, dy, dist, math.sin(angle), math.cos(angle),
                1.0 if bool(p.get('teammate')) else 0.0,
                1.0 if bool(p.get('keeper')) else 0.0,
                1.0 if bool(p.get('actor')) else 0.0,
            ])
    valid_count = len(players)
    players = players[:max_players]
    valid_count = min(valid_count, max_players)
    if not players:
        players = [[0.0] * 8]
    return players, valid_count

class EventTokenEncoder(nn.Module):
    def __init__(self, vocab_sizes, numeric_dim, d_model, dropout=0.1):
        super().__init__()
        self.features = list(vocab_sizes.keys())
        self.safe_names = [f'f{i}' for i in range(len(self.features))]
        self.name_map = dict(zip(self.features, self.safe_names))
        self.value_embeds = nn.ModuleDict({self.name_map[f]: nn.Embedding(vocab_sizes[f], d_model) for f in self.features})
        self.feature_embeds = nn.Embedding(len(self.features), d_model)
        self.numeric_proj = nn.Sequential(nn.Linear(numeric_dim, d_model), nn.GELU(), nn.Linear(d_model, d_model))
        self.dropout = nn.Dropout(dropout)
        self.register_buffer('feature_idx', torch.arange(len(self.features), dtype=torch.long), persistent=False)
    def forward(self, feat_ids, numeric_values):
        value_tokens = []
        for i, feat in enumerate(self.features):
            value_tokens.append(self.value_embeds[self.name_map[feat]](feat_ids[:, i]))
        value_tokens = torch.stack(value_tokens, dim=1)
        feat_emb = self.feature_embeds(self.feature_idx.to(feat_ids.device))
        feat_tokens = value_tokens + feat_emb.unsqueeze(0)
        numeric_token = self.numeric_proj(numeric_values).unsqueeze(1)
        event_tokens = self.dropout(torch.cat([numeric_token, feat_tokens], dim=1))
        event_mask = torch.ones(event_tokens.shape[:2], dtype=torch.bool, device=event_tokens.device)
        return event_tokens, event_mask

class RelationalSelfAttention(nn.Module):
    def __init__(self, d_model, num_heads, dropout=0.1):
        super().__init__()
        self.d_model = d_model
        self.num_heads = num_heads
        self.head_dim = d_model // num_heads
        self.scale = self.head_dim ** -0.5
        self.qkv = nn.Linear(d_model, d_model * 3)
        self.out_proj = nn.Linear(d_model, d_model)
        hidden = max(16, d_model // 8)
        self.rel_bias = nn.Sequential(nn.Linear(5, hidden), nn.GELU(), nn.Linear(hidden, 1))
        self.dropout = nn.Dropout(dropout)
    def _pairwise_bias(self, coords):
        diff = coords[:, :, None, :] - coords[:, None, :, :]
        dist = torch.linalg.norm(diff, dim=-1)
        angle = torch.atan2(diff[..., 1], diff[..., 0] + 1e-8)
        rel = torch.stack([diff[..., 0], diff[..., 1], dist, torch.sin(angle), torch.cos(angle)], dim=-1)
        return self.rel_bias(rel).squeeze(-1)
    def forward(self, x, coords, mask):
        bsz, n, _ = x.shape
        qkv = self.qkv(x).reshape(bsz, n, 3, self.num_heads, self.head_dim).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]
        scores = torch.matmul(q, k.transpose(-2, -1)) * self.scale
        scores = scores + self._pairwise_bias(coords).unsqueeze(1)
        scores = scores.masked_fill(~mask[:, None, None, :], -1e4)
        attn = self.dropout(torch.softmax(scores, dim=-1))
        out = torch.matmul(attn, v) * mask[:, None, :, None]
        out = out.transpose(1, 2).contiguous().view(bsz, n, self.d_model)
        return self.out_proj(out)

class RelationalTransformerBlock(nn.Module):
    def __init__(self, d_model, num_heads, dropout=0.1):
        super().__init__()
        self.norm1 = nn.LayerNorm(d_model)
        self.attn = RelationalSelfAttention(d_model, num_heads, dropout)
        self.norm2 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(nn.Linear(d_model, d_model * 4), nn.GELU(), nn.Dropout(dropout), nn.Linear(d_model * 4, d_model), nn.Dropout(dropout))
    def forward(self, x, coords, mask):
        x = x + self.attn(self.norm1(x), coords, mask)
        x = x * mask.unsqueeze(-1)
        x = x + self.ff(self.norm2(x))
        x = x * mask.unsqueeze(-1)
        return x

class FrameGraphEncoder(nn.Module):
    def __init__(self, player_dim, d_model, num_heads, num_layers, dropout=0.1):
        super().__init__()
        self.input_proj = nn.Sequential(nn.Linear(player_dim, d_model), nn.GELU(), nn.Linear(d_model, d_model))
        self.layers = nn.ModuleList([RelationalTransformerBlock(d_model, num_heads, dropout) for _ in range(num_layers)])
        self.dropout = nn.Dropout(dropout)
    def forward(self, player_tokens, player_mask):
        x = self.dropout(self.input_proj(player_tokens)) * player_mask.unsqueeze(-1)
        coords = player_tokens[..., :2]
        for layer in self.layers:
            x = layer(x, coords, player_mask)
        return x

class EventConditionedSceneEncoder(nn.Module):
    def __init__(self, vocab_sizes, numeric_dim, player_dim=8, d_model=192, out_dim=128, event_layers=2, frame_layers=2, num_heads=6, dropout=0.1):
        super().__init__()
        self.event_tokens = EventTokenEncoder(vocab_sizes, numeric_dim, d_model, dropout)
        self.event_query = nn.Parameter(torch.randn(1, 1, d_model) * 0.02)
        event_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=num_heads, dim_feedforward=d_model * 4, dropout=dropout, batch_first=True, activation='gelu')
        self.event_encoder = nn.TransformerEncoder(event_layer, num_layers=event_layers)
        self.frame_encoder = FrameGraphEncoder(player_dim, d_model, num_heads, frame_layers, dropout)
        self.null_scene_token = nn.Parameter(torch.zeros(1, 1, d_model))
        self.scene_cross_attn = nn.MultiheadAttention(embed_dim=d_model, num_heads=num_heads, dropout=dropout, batch_first=True)
        self.final_norm = nn.LayerNorm(d_model)
        self.out_proj = nn.Linear(d_model, out_dim)
    def forward(self, feat_ids, numeric_values, frame_tokens, frame_mask):
        batch_size = feat_ids.shape[0]
        event_tokens, event_mask = self.event_tokens(feat_ids, numeric_values)
        ev_query = self.event_query.expand(batch_size, -1, -1)
        event_input = torch.cat([ev_query, event_tokens], dim=1)
        event_input_mask = torch.cat([torch.ones(batch_size, 1, dtype=torch.bool, device=feat_ids.device), event_mask], dim=1)
        event_hidden = self.event_encoder(event_input, src_key_padding_mask=~event_input_mask)
        frame_hidden = self.frame_encoder(frame_tokens, frame_mask)
        query = event_hidden[:, :1, :]
        null_scene = self.null_scene_token.expand(batch_size, -1, -1)
        scene_tokens = torch.cat([null_scene, frame_hidden], dim=1)
        scene_mask = torch.cat([torch.ones(batch_size, 1, dtype=torch.bool, device=feat_ids.device), frame_mask], dim=1)
        cross_out, _ = self.scene_cross_attn(query=query, key=scene_tokens, value=scene_tokens, key_padding_mask=~scene_mask, need_weights=False)
        fused = self.final_norm(query + cross_out).squeeze(1)
        return {'embedding': self.out_proj(fused)}

event_ckpt = torch.load(EVENT_ENCODER_CKPT, map_location='cpu', weights_only=False)
feature_vocab = event_ckpt['feature_vocab']
features = event_ckpt['features']
enc_args = event_ckpt.get('args', {})
vocab_sizes = {k: len(v) for k, v in feature_vocab.items()}
encoder = EventConditionedSceneEncoder(
    vocab_sizes=vocab_sizes,
    numeric_dim=8,
    player_dim=8,
    d_model=int(enc_args.get('d_model', 192)),
    out_dim=int(enc_args.get('out_dim', 128)),
    event_layers=int(enc_args.get('event_layers', 2)),
    frame_layers=int(enc_args.get('frame_layers', 2)),
    num_heads=int(enc_args.get('num_heads', 6)),
).to(device)
encoder.load_state_dict(event_ckpt['model'], strict=False)
encoder.eval()

class PlayerBERT(nn.Module):
    def __init__(self, embed_dim=128, nhead=4, num_layers=2, max_len=256):
        super().__init__()
        self.pos_embed = nn.Embedding(max_len, embed_dim)
        encoder_layer = nn.TransformerEncoderLayer(d_model=embed_dim, nhead=nhead, batch_first=True)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.mask_token = nn.Parameter(torch.zeros(embed_dim))
    def forward(self, x, attn_mask):
        bsz, seq_len, _ = x.shape
        pos = torch.arange(seq_len, device=x.device).unsqueeze(0).repeat(bsz, 1)
        x = x + self.pos_embed(pos)
        return self.encoder(x, src_key_padding_mask=~attn_mask)

playerbert_state = torch.load(PLAYERBERT_CKPT, map_location='cpu', weights_only=False)
EMBED_DIM = int(playerbert_state.get('embed_dim', enc_args.get('out_dim', 128)))
playerbert = PlayerBERT(
    embed_dim=EMBED_DIM,
    nhead=int(playerbert_state.get('nhead', 4)),
    num_layers=int(playerbert_state.get('num_layers', 2)),
    max_len=int(playerbert_state.get('max_len', 256)),
).to(device)
playerbert.load_state_dict(playerbert_state['playerbert'])
playerbert.eval()

def build_feat_ids(ev):
    ids = []
    for feat in features:
        val = normalize_value(ev.get(feat))
        ids.append(feature_vocab[feat].get(val, 0))
    return ids

def compact_event(ev):
    frame_tokens, frame_valid_count = extract_freeze_frame(ev, max_players=22)
    return {
        'period': ev.get('period', 0),
        'minute': ev.get('minute', 0),
        'second': ev.get('second', 0),
        'timestamp': ev.get('timestamp', ''),
        'index': ev.get('index', 0),
        'feat_ids': build_feat_ids(ev),
        'numeric': extract_numeric(ev),
        'frame_tokens': frame_tokens,
        'frame_valid_count': frame_valid_count,
    }

def encode_event_sequence(seq):
    feat_ids = torch.tensor([ev['feat_ids'] for ev in seq], dtype=torch.long, device=device)
    numeric = torch.tensor([ev['numeric'] for ev in seq], dtype=torch.float32, device=device)
    max_players = max(len(ev['frame_tokens']) for ev in seq)
    frame_tokens = torch.zeros(len(seq), max_players, 8, dtype=torch.float32, device=device)
    frame_mask = torch.zeros(len(seq), max_players, dtype=torch.bool, device=device)
    for i, ev in enumerate(seq):
        frame = torch.tensor(ev['frame_tokens'], dtype=torch.float32, device=device)
        frame_tokens[i, :frame.shape[0]] = frame
        valid_count = min(ev['frame_valid_count'], frame.shape[0])
        if valid_count > 0:
            frame_mask[i, :valid_count] = True
    with torch.no_grad():
        out = encoder(feat_ids=feat_ids, numeric_values=numeric, frame_tokens=frame_tokens, frame_mask=frame_mask)
    return out['embedding']

print('Loaded V2 event encoder and PlayerBERT')

# %%
def iter_windows(events, max_len=256, stride=128):
    if len(events) <= max_len:
        yield events
    else:
        for i in range(0, len(events) - max_len + 1, stride):
            yield events[i:i + max_len]

def flush_match(match_sequences, player_chunk_embeddings):
    with torch.no_grad():
        for player_id, events in match_sequences.items():
            if not events:
                continue
            events.sort(key=lambda e: (e['period'], e['minute'], e['second'], e['timestamp'], e['index']))
            for window in iter_windows(events, max_len=SEQ_MAX_LEN, stride=SEQ_STRIDE):
                event_emb = encode_event_sequence(window).unsqueeze(0)
                attn_mask = torch.ones(1, event_emb.shape[1], dtype=torch.bool, device=device)
                token_h = playerbert(event_emb, attn_mask)
                pooled = token_h[0, attn_mask[0]].mean(dim=0)
                player_chunk_embeddings[str(player_id)].append(pooled.cpu())

match_gender_map = build_match_gender_map(
    local_root=STATSBOMB_OPEN_DATA_ROOT,
    cache_path=MATCH_GENDER_CACHE,
)
print('Match gender entries:', len(match_gender_map))

player_chunk_embeddings = defaultdict(list)
player_names = {}
player_gender_counts = defaultdict(Counter)
current_match_id = None
match_sequences = defaultdict(list)
rows_seen = 0

for ev in iter_json_objects(DATA_PATH):
    match_id = ev.get('match_id')
    player_id = ev.get('player.id')
    player_name = ev.get('player.name')
    if match_id is None or player_id is None:
        continue
    if current_match_id is None:
        current_match_id = match_id
    if match_id != current_match_id:
        flush_match(match_sequences, player_chunk_embeddings)
        match_sequences = defaultdict(list)
        current_match_id = match_id
    match_sequences[player_id].append(compact_event(ev))
    if player_name is not None:
        player_names[str(player_id)] = player_name
    gender = match_gender_map.get(str(match_id))
    if gender is not None:
        player_gender_counts[str(player_id)][gender] += 1
    rows_seen += 1
    if MAX_ROWS is not None and rows_seen >= MAX_ROWS:
        break

if match_sequences:
    flush_match(match_sequences, player_chunk_embeddings)

player_ids = sorted(player_chunk_embeddings.keys(), key=lambda x: int(x))
embeddings = []
player_metadata = {}
for pid in player_ids:
    stacked = torch.stack(player_chunk_embeddings[pid], dim=0)
    embeddings.append(stacked.mean(dim=0))
    player_metadata[pid] = {
        'name': player_names.get(pid),
        'gender': majority_label(player_gender_counts.get(pid)),
    }
emb_matrix = torch.stack(embeddings, dim=0)

torch.save({'player_ids': player_ids, 'embeddings': emb_matrix}, EMB_OUT)
with NAME_OUT.open('w', encoding='utf-8') as f:
    json.dump(player_names, f, ensure_ascii=False, indent=2)
with META_OUT.open('w', encoding='utf-8') as f:
    json.dump(player_metadata, f, ensure_ascii=False, indent=2)

print('Rows seen:', rows_seen)
print('Players embedded:', len(player_ids))
print('Embedding matrix shape:', tuple(emb_matrix.shape))
print('Saved embeddings:', EMB_OUT)
print('Saved names:', NAME_OUT)
print('Saved metadata:', META_OUT)

# %%
emb_data = torch.load(EMB_OUT, map_location='cpu', weights_only=False)
player_ids = emb_data['player_ids']
emb_matrix = emb_data['embeddings']
with NAME_OUT.open('r', encoding='utf-8') as f:
    player_names = json.load(f)

if META_OUT.exists():
    with META_OUT.open('r', encoding='utf-8') as f:
        player_metadata = json.load(f)
else:
    print('Player metadata cache missing; rebuilding metadata from JSONL...')
    match_gender_map = build_match_gender_map(
        local_root=STATSBOMB_OPEN_DATA_ROOT,
        cache_path=MATCH_GENDER_CACHE,
    )
    player_metadata = build_player_metadata(DATA_PATH, player_ids, match_gender_map, max_rows=MAX_ROWS)
    with META_OUT.open('w', encoding='utf-8') as f:
        json.dump(player_metadata, f, ensure_ascii=False, indent=2)
    print('Saved metadata:', META_OUT)

def find_similar_players(player_query, top_k=10, same_gender_only=True):
    query_id = None
    for pid in player_ids:
        name = player_names.get(str(pid)) or player_names.get(pid)
        if name == player_query:
            query_id = pid
            break
    if query_id is None:
        print('Player not found:', player_query)
        return

    query_meta = player_metadata.get(str(query_id), {})
    query_gender = query_meta.get('gender')
    id_to_idx = {pid: i for i, pid in enumerate(player_ids)}
    qidx = id_to_idx[query_id]
    query_vec = emb_matrix[qidx]
    query_vec = query_vec / (query_vec.norm() + 1e-8)
    embs = emb_matrix / (emb_matrix.norm(dim=1, keepdim=True) + 1e-8)
    sims = torch.mv(embs, query_vec)
    ranked = torch.argsort(sims, descending=True)

    header = f'Top {top_k} similar players to {player_query}'
    if same_gender_only and query_gender:
        header += f' ({query_gender}-only filter)'
    print(header + ':')

    count = 0
    for idx in ranked.tolist():
        pid = player_ids[idx]
        name = player_names.get(str(pid)) or player_names.get(pid)
        if name == player_query:
            continue
        candidate_gender = (player_metadata.get(str(pid)) or {}).get('gender')
        if same_gender_only and query_gender and candidate_gender != query_gender:
            continue
        print(name, float(sims[idx]), candidate_gender)
        count += 1
        if count >= top_k:
            break

PLAYER_QUERY = 'Wojciech Szczęsny'
find_similar_players(PLAYER_QUERY, top_k=TOP_K)

# %%
PLAYER_QUERY = 'Lionel Andrés Messi Cuccittini'
find_similar_players(PLAYER_QUERY, top_k=TOP_K)
